# %% [markdown]
# # Rule Based Association Pattern mining to find the sumarized the terms and condition
# Team members:
# Nikhil Gola(MT18129) Ridha Juneja(MT18009) Saru Brar(MT18014) Yogesh Pandey(MT18140)
# *****************************************************************************************
#
# Importing all the necessary libraries required for the Rule based Association Pattern mining

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pickle
from nltk.stem import WordNetLemmatizer

# %%
import nltk
from collections import Counter
import numpy as np

# %%
import os
import re
import copy
import time

# %% [markdown]
# Setting the min_support and min_confidence value for the Confidence table

# %%
min_support=0.0
min_confidence=0.99

# %% [markdown]
# Loading the pickle word dictionary pickle file after preprocessing of the data (pickle file will act as a cache to our System)

# %%
def loadWordDictionaryPickle():
    f=open('Pickled Data/word_Dictionary.pickle','rb')
    vocab=pickle.load(f)
    f.close()
    return vocab

# %% [markdown]
# Loading the word frequncy pickle file from preprocessed data

# %%
def loadWordFrequencyPickle():
    f1=open('Pickled Data/word_Frequency.pickle','rb')
    DocVocab=pickle.load(f1)
    #print(DocVocab['Facebook'])
    f1.close()
    return DocVocab

# %% [markdown]
# Loading the unique word pickle from the preprocessed data

# %%
def loadUniqueWordPickle(): 
    f1=open('Pickled Data/unique_Wordset.pickle','rb')
    unique_word=pickle.load(f1)
    unique_word=list(unique_word)
    f1.close()
    return unique_word

# %% [markdown]
# Calculating word frequency in the training set(corpus) and calculating the probability of word for occuring in corpus and the tfidf values for every word in the corpus

# %%
def uniqueWordFrequency(DocVocab):
    Word_Set_frequency={}
    wordSetSupport = {}
    tfidf_dict={}
    maxDoc=len(DocVocab.keys())
    print(maxDoc)
    for key in DocVocab.keys():
        for word in DocVocab[key]:
            if Word_Set_frequency.get(word) ==None:
                Word_Set_frequency[word]=DocVocab[key][word]
                if DocVocab[key][word]==0:
                    wordSetSupport[word]=0.0
                else:
                    wordSetSupport[word]=1.0
            else:
                if DocVocab[key][word]==0:
                    wordSetSupport[word]+=0.0
                else:
                    wordSetSupport[word]+=1.0
                Word_Set_frequency[word]+=DocVocab[key][word]
    #print(wordSetSupport['combine'])
    total1_sum=np.sum([Word_Set_frequency[key] for key in Word_Set_frequency.keys()])
    for key in wordSetSupport.keys():
            wordSetSupport[key]=wordSetSupport[key]/maxDoc
            tfidf_dict[key]=wordSetSupport[key]*(Word_Set_frequency[key]/(1.0*total1_sum))
    return Word_Set_frequency,wordSetSupport,tfidf_dict

# %% [markdown]
# Filtering the words from the wordset based upon their frequency which above the mean of frequency

# %%
#print([Word_Set_frequency[key]  for key in Word_Set_frequency.keys()])

#print(mean1)
#median1=np.median([Word_Set_frequency[key]  for key in Word_Set_frequency.keys()])
#print(median1)
#threshold=np.array([Word_Set_frequency[key]  for key in Word_Set_frequency.keys()])
#threshold1=np.reshape(len(threshold),1)
#kmeans = KMeans(n_clusters=4, random_state=0).fit(threshold1)
#print(kmeans)
def filterWordSetFrequencySupport(mean1,Word_Set_frequency,wordSetSupport):
    req_Dic={}
    req_Dic_Sup={}
    for key in Word_Set_frequency.keys():
        if Word_Set_frequency[key]>mean1:
            req_Dic[key]=Word_Set_frequency[key]
    for key in req_Dic.keys():
        req_Dic_Sup[key]=wordSetSupport[key]
    return req_Dic,req_Dic_Sup

# %%
'''fp = open('TFIDF_values.pickle','rb')
tfidf_values={}
tfidf = pickle.load(fp)
#print(tfidf['Google'])
for key in tfidf.keys():
    for wordkey in tfidf[key].keys():
        if tfidf_values.get(wordkey)==None:
            tfidf_values[wordkey]=tfidf[key][wordkey]
        else:
            tfidf_values[wordkey]+=tfidf[key][wordkey]
for key in tfidf_values.keys():
    tfidf_values[key] = tfidf_values[key]/len(tfidf.keys())
#print(tfidf_values[''])
'''
# Out:
# "fp = open('TFIDF_values.pickle','rb')\ntfidf_values={}\ntfidf = pickle.load(fp)\n#print(tfidf['Google'])\nfor key in tfidf.keys():\n    for wordkey in tfidf[key].keys():\n        if tfidf_values.get(wordkey)==None:\n            tfidf_values[wordkey]=tfidf[key][wordkey]\n        else:\n            tfidf_values[wordkey]+=tfidf[key][wordkey]\nfor key in tfidf_values.keys():\n    tfidf_values[key] = tfidf_values[key]/len(tfidf.keys())\n#print(tfidf_values[''])\n"

# %%
'''def returnItemsWithMinSupport(vocab):
        maxDoc=len(vocab.keys())
        Support_Score={}
        for key in vocab.keys():
            for words in vocab[key]:
                if Support_Score.get(words) is None:
                    Support_Score[words]=1
                else:
                    Support_Score[words]+=1
        for key in Support_Score.keys():
            Support_Score[key]=Support_Score[key]/maxDoc
        return Support_Score
'''
# Out:
# 'def returnItemsWithMinSupport(vocab):\n        maxDoc=len(vocab.keys())\n        Support_Score={}\n        for key in vocab.keys():\n            for words in vocab[key]:\n                if Support_Score.get(words) is None:\n                    Support_Score[words]=1\n                else:\n                    Support_Score[words]+=1\n        for key in Support_Score.keys():\n            Support_Score[key]=Support_Score[key]/maxDoc\n        return Support_Score\n'

# %%
def getData():
    words=[]
    with open("data1.txt","r") as f:
        x  = f.readlines()
        for word in x:
            words.append(word.replace("\n",""))
            
    return words

# %%
def FilterDictionary(A,Support_Score,unique_word):
    filteredDict=[]
    SScore={}
    for word in A:
        if word in unique_word:
            filteredDict.append(word)
            SScore[word]=Support_Score[word]
    return filteredDict,SScore

# %%
def LemmatizeWord(A):
    WN=WordNetLemmatizer()
    i=0;
    maxLen=len(A)
    while i<maxLen:
        A[i]=WN.lemmatize(A[i])
        i+=1
    return A

# %%
def ListToDic(vocab):
    my_dict={}
    for doc in vocab.keys():
        my_dict = {k: 0 for k in vocab[doc] }
        vocab[doc]=my_dict
    
    return vocab

# %%
def confidence(A,B,vocab):
    ScoreMatrix=np.zeros((len(A),len(B)))
    #print(len(B))
    #print(len(A))
    for index1,word1 in enumerate(A):# A is list of words
        for index2,word2 in enumerate(B):
            common=0
            totA=0
            for doc in vocab.keys():
                if  vocab[doc].get(word1) is not None :
                    totA+=1
                    if vocab[doc].get(word2) is not None:
                        common+=1
                    
            if totA==0:
                print(word1,word2)
            ScoreMatrix[index1][index2]=common/totA
    return ScoreMatrix

# %%
#print(len(A))
#print(requiredDicti['software'])
#print('software' in B )
#print(len(B))
#print(B)
#print(Ascore)

# %%
def SelectAssociationRules(confidenceMatrix,min_support,min_confidence,A,B,Support_Score):
    row,col=confidenceMatrix.shape
    #print(row,col)
    required={}
    for i in range(0,row):
        for j in range(0,col):
            word=A[i]
            score=Support_Score[word]
            word2=B[j]
            if confidenceMatrix[i][j]>=min_confidence and score>min_support:
                if required.get(word) ==None and (word!='' and word2!='') :
                    required[word]=[word2]
                else:
                    if (word!='' and word2!=''):
                        required[word].append(word2)
                print(word,'-->',word2)
                #print("\n")
    return required

# %%
'''def MeanOFMean(confidenceMatrix):
    mean1=[]
    row,col=confidenceMatrix.shape
    for i in range(0,row):
            mean1.append(np.median(confidenceMatrix[i]))
#             print(mean1)
    return np.mean(mean1)
MeanOFMean(confidenceMatrix)
'''
# Out:
# 'def MeanOFMean(confidenceMatrix):\n    mean1=[]\n    row,col=confidenceMatrix.shape\n    for i in range(0,row):\n            mean1.append(np.median(confidenceMatrix[i]))\n#             print(mean1)\n    return np.mean(mean1)\nMeanOFMean(confidenceMatrix)\n'

# %%
def Find(string): 
    # findall() has been used  
    # with valid conditions for urls in string 
    url = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+] |[!*\(\), ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', string) 
    return url

# %%
def printSummary(rule_Dict,outputfile):
    #list_of_lines_to_print = []
    #print(rule_Dict.keys())
    
    #print(rule_Dict['personal_information']['DuckDuckGo does not collect or share personal information'])
    
    #rule_Dict[key][key2] for key2 in rule_Dict[key]
    with open(outputfile,"w") as file1:
        for key in rule_Dict.keys():
            testList=rule_Dict[key]
            #print([ele[0] for ele in testList])
            mean8 = np.mean([ele[0][1] for ele in testList])
            #print(mean8)
            for rows in testList:
                #print(rows[0])
                if rows[0][1]>=mean8:
                    #rows[0][0]=rows[0][0].decode('utf-8','ignore')
                    file1.write(rows[0][0]+'\n')
               
                    #list_of_lines_to_print.append(key2)

# %%
def doSummarization(filename,filepath,rules,tfidf_dict):
    outputfile = filepath+'summary/'+filename[:-4]+'Summary'+'.txt'
    filename = filepath+filename
    linesData =[]
    rule_Dict={}
    with open(filename,encoding="utf8") as file:
        data = file.readlines()
        #print(data)
        
        for line2 in data:
            linedata=line2.split(".")
            for line in linedata:
                s = Find(line)
                #print("url:", s)
                if len(s)<=0:
                    
                    line = line.replace("\n","")
                    line = line.replace("-","")
                    line1=line.lower()
                    #print("line:",line)
                    tokens=nltk.word_tokenize(line1)
                    if len(tokens)>1:
                        tokens=nltk.word_tokenize(line)
                        #print(tokens)
                        flag=0
                        weight=0
                        line_dict=[]
                        for token in tokens:
                            if rules.get(token)!=None:
                                for word2 in rules[token]:
                                    if word2 in tokens:
                                        flag=1
                                        #print("Printing this line beacuse of ",token,"-->",word2)
                                        #print('--> ',line,".\n")
                                        linesData.append(line)
                                        for token1 in tokens:
                                            if tfidf_dict.get(token1) is not None:
                                                weight=weight+tfidf_dict[token1]
                                        line_dict.append([line,weight])
                                        break
                            if flag==1:
                                break
                        
                        if flag==1:
                                w1=token.lower()
                                w2=word2.lower()
                                str1=w1+'_'+w2
                                if rule_Dict.get(str1) is None:
                                    rule_Dict[str1]=[line_dict]
                                else:
                                    rule_Dict[str1].append(line_dict)

    #print(len(linesData))
   
    printSummary(rule_Dict,outputfile)

# %%
def main():
    vocab = loadWordDictionaryPickle()
    Support_Score={}
    DocVocab = loadWordFrequencyPickle()
    Word_Set_frequency,wordSetSupport,tfidf_dict=uniqueWordFrequency(DocVocab)
    mean1=np.mean([Word_Set_frequency[key]  for key in Word_Set_frequency.keys()])
    req_Dic,req_Dic_Sup = filterWordSetFrequencySupport(mean1,Word_Set_frequency,wordSetSupport)
    unique_word = loadUniqueWordPickle()
    vocab=ListToDic(vocab)
    A=getData()
    requiredDicti ={}
    A,Ascore=FilterDictionary(A,wordSetSupport,unique_word)
    A=LemmatizeWord(A)
    for key in req_Dic.keys():
        if key not in A:
            requiredDicti[key]=req_Dic[key]
    B=[]
    for item,value in requiredDicti.items():
        B.append(item)
    confidenceMatrix=confidence(A,B,vocab)
    print(confidenceMatrix)
    rules=SelectAssociationRules(confidenceMatrix,min_support,min_confidence,A,B,wordSetSupport)
    test_path = "Datasets/testdata/"
    test_files = os.listdir(test_path)  
    print(test_files)
    #doSummarization("Datasets/testdata/Github.txt")
    for file in test_files:
        if os.path.isdir(test_path+file):
            pass
        else:
            print("doing for ",file)
            doSummarization(file,test_path,rules,tfidf_dict)

# %%
def similarity(file1,file2,name1,name2):
    count=0
    data = open(file2,'rb')
    listoffile=[]
    for line in data:
        listoffile.append(line.lower())
    #print("list:",listoffile)
    data1 = open(file1,'rb')
    for line1 in data1:
        #print("line1:",line1.lower())
        if line1.lower() in listoffile:
            count+=1
    acc = count/len(listoffile)*100
    print("Accuracy for ",name1," and ",name2," is : ",acc,"%")

# %%
main()

sum_path = "Datasets/testdata/summary/"
grnd_path ="Datasets/GroundTruth/"
sum_files = os.listdir(sum_path)
grnd_files = os.listdir(grnd_path)

#print(sum_files)
#print(grnd_path)
#doSummarization("Datasets/testdata/Github.txt")
for i in range(0,len(sum_files)):
    if os.path.isdir(sum_path+sum_files[i]):
        pass
    else:
        similarity(sum_path+sum_files[i],grnd_path+grnd_files[i],sum_files[i],grnd_files[i])
# Out:
# 158
# [[1.         0.33333333 0.33333333 ... 0.5        0.         0.5       ]
#  [0.25       0.25       0.         ... 0.5        0.         0.25      ]
#  [0.42105263 0.15789474 0.28947368 ... 0.28947368 0.02631579 0.26315789]
#  ...
#  [1.         0.875      0.375      ... 0.875      0.         0.25      ]
#  [0.375      0.5        0.375      ... 0.25       0.         0.        ]
#  [0.65277778 0.39583333 0.28472222 ... 0.36805556 0.00694444 0.24305556]]
# discrimination --> violate
# discrimination --> result
# discrimination --> user
# discrimination --> connection
# discrimination --> violation
# discrimination --> activity
# discrimination --> sexual
# discrimination --> include
# discrimination --> access
# discrimination --> consent
# discrimination --> subject
# discrimination --> person
# discrimination --> purpose
# discrimination --> law
# discrimination --> additional
# discrimination --> available
# discrimination --> follow
# discrimination --> form
# discrimination --> basis
# discrimination --> may
# discrimination --> provide
# discrimination --> respect
# discrimination --> take
# discrimination --> account
# discrimination --> encourage
# discrimination --> way
# discrimination --> one
# discrimination --> information
# discrimination --> make
# discrimination --> without
# discrimination --> notice
# discrimination --> necessary
# discrimination --> comply
# discrimination --> post
# discrimination --> delete
# discrimination --> use
# discrimination --> content
# discrimination --> explicit
# discrimination --> service
# cloud --> read
# cloud --> cannot
# cloud --> perform
# cloud --> order
# cloud --> user
# cloud --> request
# cloud --> applicable
# cloud --> work
# cloud --> server
# cloud --> payment
# cloud --> associate
# cloud --> contact
# cloud --> right
# cloud --> reason
# cloud --> secure
# cloud --> also
# cloud --> limit
# cloud --> include
# cloud --> transaction
# cloud --> whether
# cloud --> network
# cloud --> need
# cloud --> notify
# cloud --> legal
# cloud --> depend
# cloud --> access
# cloud --> direct
# cloud --> require
# cloud --> similar
# cloud --> communication
# cloud --> provider
# cloud --> collect
# cloud --> share
# cloud --> purpose
# cloud --> law
# cloud --> operate
# cloud --> like
# cloud --> via
# cloud --> complete
# cloud --> set
# cloud --> web
# cloud --> address
# cloud --> may
# cloud --> protect
# cloud --> provide
# cloud --> note
# cloud --> end
# cloud --> take
# cloud --> account
# cloud --> report
# cloud --> interest
# cloud --> term
# cloud --> name
# cloud --> obtain
# cloud --> affiliate
# cloud --> type
# cloud --> party
# cloud --> always
# cloud --> detail
# cloud --> data
# cloud --> receive
# cloud --> page
# cloud --> information
# cloud --> give
# cloud --> make
# cloud --> different
# cloud --> without
# cloud --> please
# cloud --> change
# cloud --> relate
# cloud --> feature
# cloud --> necessary
# cloud --> responsible
# cloud --> contract
# cloud --> process
# cloud --> support
# cloud --> send
# cloud --> use
# cloud --> content
# cloud --> communicate
# cloud --> review
# cloud --> choose
# cloud --> control
# cloud --> place
# cloud --> service
# cloud --> wish
# cloud --> allow
# cloud --> store
# cookie --> right
# cookie --> also
# cookie --> include
# cookie --> access
# cookie --> purpose
# cookie --> may
# cookie --> provide
# cookie --> receive
# cookie --> information
# cookie --> make
# cookie --> please
# cookie --> use
# cookie --> content
# cookie --> service
# domain --> applicable
# domain --> right
# domain --> also
# domain --> include
# domain --> whether
# domain --> access
# domain --> subject
# domain --> law
# domain --> may
# domain --> provide
# domain --> term
# domain --> party
# domain --> make
# domain --> without
# domain --> change
# domain --> use
# domain --> service
# separation --> violate
# separation --> bring
# separation --> forth
# separation --> policy
# separation --> cannot
# separation --> serve
# separation --> regulation
# separation --> perform
# separation --> vary
# separation --> conduct
# separation --> exercise
# separation --> list
# separation --> see
# separation --> result
# separation --> day
# separation --> another
# separation --> sensitive
# separation --> order
# separation --> user
# separation --> connection
# separation --> analytics
# separation --> request
# separation --> long
# separation --> across
# separation --> claim
# separation --> applicable
# separation --> violation
# separation --> others
# separation --> example
# separation --> block
# separation --> incorrect
# separation --> transfer
# separation --> disclosure
# separation --> identifiable
# separation --> accurate
# separation --> commit
# separation --> work
# separation --> nature
# separation --> sale
# separation --> seller
# separation --> commission
# separation --> disable
# separation --> parent
# separation --> server
# separation --> conflict
# separation --> website
# separation --> describe
# separation --> able
# separation --> payment
# separation --> buy
# separation --> activity
# separation --> associate
# separation --> contact
# separation --> right
# separation --> implement
# separation --> longer
# separation --> device
# separation --> foreign
# separation --> message
# separation --> measure
# separation --> deem
# separation --> relevant
# separation --> independent
# separation --> secure
# separation --> unauthorized
# separation --> clear
# separation --> also
# separation --> illegal
# separation --> delivery
# separation --> personalize
# separation --> dispute
# separation --> two
# separation --> related
# separation --> limit
# separation --> acknowledge
# separation --> allege
# separation --> include
# separation --> base
# separation --> material
# separation --> let
# separation --> except
# separation --> benefit
# separation --> transaction
# separation --> regular
# separation --> confirm
# separation --> appropriate
# separation --> whether
# separation --> bank
# separation --> network
# separation --> need
# separation --> minor
# separation --> contain
# separation --> notify
# separation --> withdraw
# separation --> legal
# separation --> depend
# separation --> setting
# separation --> determine
# separation --> company
# separation --> represent
# separation --> access
# separation --> agent
# separation --> direct
# separation --> require
# separation --> release
# separation --> copyright
# separation --> otherwise
# separation --> child
# separation --> amend
# separation --> permit
# separation --> card
# separation --> similar
# separation --> would
# separation --> national
# separation --> communication
# separation --> consent
# separation --> provider
# separation --> international
# separation --> state
# separation --> collect
# separation --> contribution
# separation --> keep
# separation --> subject
# separation --> unable
# separation --> replace
# separation --> first
# separation --> effective
# separation --> transmit
# separation --> retain
# separation --> carry
# separation --> share
# separation --> locate
# separation --> help
# separation --> digital
# separation --> reasonable
# separation --> person
# separation --> continue
# separation --> purpose
# separation --> point
# separation --> law
# separation --> item
# separation --> bind
# separation --> exclusive
# separation --> disclose
# separation --> decision
# separation --> compliance
# separation --> profile
# separation --> additional
# separation --> guarantee
# separation --> electronic
# separation --> govern
# separation --> obligation
# separation --> marketing
# separation --> browse
# separation --> guardian
# separation --> affect
# separation --> like
# separation --> via
# separation --> available
# separation --> common
# separation --> enforce
# separation --> learn
# separation --> tax
# separation --> follow
# separation --> per
# separation --> act
# separation --> download
# separation --> subscription
# separation --> express
# separation --> complete
# separation --> advertising
# separation --> subsequent
# separation --> submission
# separation --> cover
# separation --> resident
# separation --> set
# separation --> receipt
# separation --> analyze
# separation --> government
# separation --> form
# separation --> basis
# separation --> applies
# separation --> address
# separation --> power
# separation --> may
# separation --> area
# separation --> show
# separation --> protect
# separation --> provide
# separation --> note
# separation --> open
# separation --> respect
# separation --> behalf
# separation --> federal
# separation --> participate
# separation --> regard
# separation --> financial
# separation --> take
# separation --> restriction
# separation --> modify
# separation --> cost
# separation --> want
# separation --> application
# separation --> update
# separation --> guest
# separation --> public
# separation --> ask
# separation --> engage
# separation --> account
# separation --> complaint
# separation --> buyer
# separation --> google
# separation --> representative
# separation --> report
# separation --> facility
# separation --> concern
# separation --> proper
# separation --> breach
# separation --> term
# separation --> name
# separation --> opportunity
# separation --> relation
# separation --> obtain
# separation --> cease
# separation --> email
# separation --> affiliate
# separation --> type
# separation --> date
# separation --> minimum
# separation --> pursuant
# separation --> party
# separation --> physical
# separation --> member
# separation --> encourage
# separation --> backup
# separation --> liable
# separation --> submit
# separation --> question
# separation --> prior
# separation --> removal
# separation --> ful
# separation --> display
# separation --> detail
# separation --> manage
# separation --> credit
# separation --> technology
# separation --> data
# separation --> gain
# separation --> limitation
# separation --> receive
# separation --> file
# separation --> internet
# separation --> view
# separation --> edit
# separation --> preference
# separation --> trade
# separation --> entitle
# separation --> part
# separation --> original
# separation --> ad
# separation --> specify
# separation --> decide
# separation --> site
# separation --> country
# separation --> resolve
# separation --> page
# separation --> potential
# separation --> cooky
# separation --> agreement
# separation --> accessible
# separation --> collection
# separation --> local
# separation --> registration
# separation --> find
# separation --> enforcement
# separation --> browser
# separation --> transmission
# separation --> username
# separation --> processing
# separation --> governmental
# separation --> information
# separation --> system
# separation --> within
# separation --> event
# separation --> care
# separation --> make
# separation --> different
# separation --> without
# separation --> please
# separation --> option
# separation --> sit
# separation --> california
# separation --> prevent
# separation --> group
# separation --> purchase
# separation --> change
# separation --> notice
# separation --> officer
# separation --> posting
# separation --> involve
# separation --> infringe
# separation --> previous
# separation --> notification
# separation --> suspect
# separation --> relate
# separation --> visit
# separation --> mobile
# separation --> standard
# separation --> relationship
# separation --> free
# separation --> online
# separation --> advertise
# separation --> contribute
# separation --> feature
# separation --> sell
# separation --> general
# separation --> important
# separation --> ensure
# separation --> contractual
# separation --> necessary
# separation --> shall
# separation --> business
# separation --> responsible
# separation --> create
# separation --> contract
# separation --> process
# separation --> issue
# separation --> support
# separation --> believe
# separation --> european
# separation --> deactivate
# separation --> membership
# separation --> send
# separation --> comply
# separation --> assist
# separation --> time
# separation --> age
# separation --> respond
# separation --> post
# separation --> functionality
# separation --> delete
# separation --> apply
# separation --> use
# separation --> content
# separation --> communicate
# separation --> automate
# separation --> review
# separation --> together
# separation --> opt
# separation --> authorization
# separation --> various
# separation --> know
# separation --> location
# separation --> infringement
# separation --> sign
# separation --> choose
# separation --> control
# separation --> place
# separation --> link
# separation --> period
# separation --> maintain
# separation --> service
# separation --> permission
# separation --> court
# separation --> source
# separation --> resolution
# separation --> authority
# separation --> along
# separation --> register
# separation --> interaction
# separation --> certain
# separation --> outside
# separation --> intend
# separation --> track
# separation --> remove
# separation --> legitimate
# separation --> safety
# separation --> close
# separation --> phone
# separation --> leave
# separation --> practice
# separation --> enter
# separation --> allow
# separation --> select
# separation --> commercial
# separation --> current
# separation --> store
# separation --> year
# separation --> forum
# encryption --> cannot
# encryption --> user
# encryption --> contact
# encryption --> also
# encryption --> include
# encryption --> need
# encryption --> access
# encryption --> require
# encryption --> otherwise
# encryption --> purpose
# encryption --> law
# encryption --> available
# encryption --> may
# encryption --> protect
# encryption --> provide
# encryption --> public
# encryption --> term
# encryption --> obtain
# encryption --> party
# encryption --> data
# encryption --> information
# encryption --> make
# encryption --> please
# encryption --> relate
# encryption --> responsible
# encryption --> create
# encryption --> post
# encryption --> use
# encryption --> content
# encryption --> know
# encryption --> link
# encryption --> service
# encryption --> allow
# hazard --> violate
# hazard --> bring
# hazard --> scope
# hazard --> read
# hazard --> policy
# hazard --> cannot
# hazard --> perform
# hazard --> vary
# hazard --> exercise
# hazard --> product
# hazard --> exceed
# hazard --> proprietary
# hazard --> list
# hazard --> result
# hazard --> year
# hazard --> designate
# abuse --> also
# abuse --> include
# abuse --> legal
# abuse --> access
# abuse --> law
# abuse --> follow
# abuse --> may
# abuse --> provide
# abuse --> account
# abuse --> information
# abuse --> make
# abuse --> without
# abuse --> use
# abuse --> service
# fraudulent --> right
# fraudulent --> include
# fraudulent --> may
# fraudulent --> provide
# fraudulent --> term
# fraudulent --> information
# fraudulent --> make
# fraudulent --> time
# fraudulent --> use
# fraudulent --> service
# asset --> user
# asset --> contact
# asset --> right
# asset --> also
# asset --> include
# asset --> whether
# asset --> access
# asset --> available
# asset --> may
# asset --> provide
# asset --> term
# asset --> information
# asset --> make
# asset --> without
# asset --> change
# asset --> use
# asset --> content
# asset --> service
# asset --> allow
# objectionable --> agree
# objectionable --> must
# objectionable --> applicable
# objectionable --> right
# objectionable --> also
# objectionable --> include
# objectionable --> warranty
# objectionable --> whether
# objectionable --> legal
# objectionable --> require
# objectionable --> permit
# objectionable --> law
# objectionable --> govern
# objectionable --> express
# objectionable --> may
# objectionable --> provide
# objectionable --> term
# objectionable --> way
# objectionable --> agreement
# objectionable --> information
# objectionable --> make
# objectionable --> without
# objectionable --> change
# objectionable --> relate
# objectionable --> responsible
# objectionable --> create
# objectionable --> use
# objectionable --> content
# objectionable --> service
# objectionable --> court
# exploit --> remain
# exploit --> also
# exploit --> include
# exploit --> legal
# exploit --> access
# exploit --> subject
# exploit --> law
# exploit --> may
# exploit --> provide
# exploit --> account
# exploit --> information
# exploit --> make
# exploit --> without
# exploit --> please
# exploit --> notice
# exploit --> create
# exploit --> time
# exploit --> use
# exploit --> content
# exploit --> service
# fraud --> policy
# fraud --> user
# fraud --> also
# fraud --> include
# fraud --> whether
# fraud --> legal
# fraud --> may
# fraud --> provide
# fraud --> term
# fraud --> part
# fraud --> information
# fraud --> make
# fraud --> please
# fraud --> change
# fraud --> time
# fraud --> use
# fraud --> content
# fraud --> service
# personal --> also
# personal --> include
# personal --> may
# personal --> provide
# personal --> information
# personal --> use
# personal --> service
# shield --> see
# shield --> user
# shield --> request
# shield --> describe
# shield --> contact
# shield --> right
# shield --> device
# shield --> also
# shield --> include
# shield --> whether
# shield --> legal
# shield --> setting
# shield --> access
# shield --> direct
# shield --> require
# shield --> provider
# shield --> collect
# shield --> keep
# shield --> subject
# shield --> share
# shield --> law
# shield --> set
# shield --> address
# shield --> may
# shield --> protect
# shield --> provide
# shield --> take
# shield --> account
# shield --> email
# shield --> party
# shield --> data
# shield --> receive
# shield --> site
# shield --> cooky
# shield --> browser
# shield --> information
# shield --> make
# shield --> please
# shield --> change
# shield --> online
# shield --> process
# shield --> send
# shield --> use
# shield --> allow
# shield --> store
# screen --> user
# screen --> also
# screen --> include
# screen --> legal
# screen --> access
# screen --> law
# screen --> may
# screen --> provide
# screen --> information
# screen --> please
# screen --> necessary
# screen --> use
# screen --> service
# ageism --> violate
# ageism --> read
# ageism --> forth
# ageism --> policy
# ageism --> reach
# ageism --> regulation
# ageism --> perform
# ageism --> conduct
# ageism --> proprietary
# ageism --> result
# ageism --> implied
# ageism --> arise
# ageism --> order
# ageism --> people
# ageism --> user
# ageism --> connection
# ageism --> agree
# ageism --> request
# ageism --> claim
# ageism --> generate
# ageism --> must
# ageism --> applicable
# ageism --> remain
# ageism --> others
# ageism --> publish
# ageism --> gift
# ageism --> work
# ageism --> reference
# ageism --> loss
# ageism --> website
# ageism --> usage
# ageism --> whole
# ageism --> describe
# ageism --> payment
# ageism --> entire
# ageism --> activity
# ageism --> associate
# ageism --> contact
# ageism --> right
# ageism --> agency
# ageism --> respective
# ageism --> deem
# ageism --> relevant
# ageism --> clear
# ageism --> course
# ageism --> also
# ageism --> illegal
# ageism --> license
# ageism --> dispute
# ageism --> limit
# ageism --> acknowledge
# ageism --> understand
# ageism --> include
# ageism --> material
# ageism --> warranty
# ageism --> except
# ageism --> whether
# ageism --> monitor
# ageism --> final
# ageism --> refer
# ageism --> network
# ageism --> cause
# ageism --> need
# ageism --> live
# ageism --> render
# ageism --> contain
# ageism --> notify
# ageism --> legal
# ageism --> beyond
# ageism --> reliance
# ageism --> joint
# ageism --> verify
# ageism --> fitness
# ageism --> company
# ageism --> bound
# ageism --> handle
# ageism --> circumstance
# ageism --> operation
# ageism --> access
# ageism --> direct
# ageism --> require
# ageism --> rule
# ageism --> copyright
# ageism --> valid
# ageism --> otherwise
# ageism --> future
# ageism --> child
# ageism --> terminate
# ageism --> consent
# ageism --> interruption
# ageism --> international
# ageism --> subject
# ageism --> share
# ageism --> avail
# ageism --> reasonable
# ageism --> continue
# ageism --> purpose
# ageism --> law
# ageism --> item
# ageism --> particular
# ageism --> pay
# ageism --> bind
# ageism --> kind
# ageism --> advertisement
# ageism --> either
# ageism --> guarantee
# ageism --> govern
# ageism --> choice
# ageism --> guardian
# ageism --> via
# ageism --> follow
# ageism --> express
# ageism --> hold
# ageism --> harmless
# ageism --> immediate
# ageism --> indemnify
# ageism --> set
# ageism --> form
# ageism --> version
# ageism --> address
# ageism --> may
# ageism --> fail
# ageism --> area
# ageism --> administer
# ageism --> constitute
# ageism --> nothing
# ageism --> protect
# ageism --> provide
# ageism --> restrict
# ageism --> unsolicited
# ageism --> hereby
# ageism --> regard
# ageism --> impersonate
# ageism --> upon
# ageism --> application
# ageism --> abide
# ageism --> public
# ageism --> ask
# ageism --> account
# ageism --> arbitration
# ageism --> imply
# ageism --> disclaimer
# ageism --> deal
# ageism --> term
# ageism --> promote
# ageism --> provision
# ageism --> external
# ageism --> relation
# ageism --> email
# ageism --> type
# ageism --> incorporate
# ageism --> minimum
# ageism --> statutory
# ageism --> party
# ageism --> encourage
# ageism --> liable
# ageism --> jurisdiction
# ageism --> question
# ageism --> convenience
# ageism --> ful
# ageism --> representation
# ageism --> warrant
# ageism --> display
# ageism --> construe
# ageism --> way
# ageism --> technology
# ageism --> data
# ageism --> limitation
# ageism --> receive
# ageism --> sole
# ageism --> mail
# ageism --> part
# ageism --> virtual
# ageism --> exist
# ageism --> false
# ageism --> reserve
# ageism --> site
# ageism --> resolve
# ageism --> disclaim
# ageism --> agreement
# ageism --> accessible
# ageism --> one
# ageism --> registration
# ageism --> find
# ageism --> governmental
# ageism --> information
# ageism --> within
# ageism --> event
# ageism --> give
# ageism --> make
# ageism --> without
# ageism --> please
# ageism --> change
# ageism --> notice
# ageism --> involve
# ageism --> unenforceable
# ageism --> medium
# ageism --> suspect
# ageism --> relate
# ageism --> accordance
# ageism --> bear
# ageism --> bigo
# ageism --> develop
# ageism --> necessary
# ageism --> shall
# ageism --> soon
# ageism --> responsible
# ageism --> create
# ageism --> matter
# ageism --> advance
# ageism --> validity
# ageism --> accord
# ageism --> responsibility
# ageism --> assist
# ageism --> time
# ageism --> age
# ageism --> revise
# ageism --> competent
# ageism --> reasonab
# ageism --> use
# ageism --> content
# ageism --> accuracy
# ageism --> consequence
# ageism --> review
# ageism --> authorization
# ageism --> special
# ageism --> force
# ageism --> attempt
# ageism --> choose
# ageism --> control
# ageism --> place
# ageism --> link
# ageism --> explicit
# ageism --> service
# ageism --> permission
# ageism --> social
# ageism --> register
# ageism --> trademark
# ageism --> certain
# ageism --> click
# ageism --> language
# ageism --> acquire
# ageism --> enter
# ageism --> allow
# ageism --> grant
# ageism --> commercial
# ageism --> current
# ageism --> unlawful
# ageism --> year
# malware --> policy
# malware --> result
# malware --> include
# malware --> legal
# malware --> access
# malware --> purpose
# malware --> may
# malware --> provide
# malware --> account
# malware --> way
# malware --> information
# malware --> make
# malware --> without
# malware --> apply
# malware --> use
# malware --> content
# malware --> service
# guard --> read
# guard --> policy
# guard --> manner
# guard --> user
# guard --> agree
# guard --> request
# guard --> applicable
# guard --> unless
# guard --> sale
# guard --> portion
# guard --> website
# guard --> establish
# guard --> activity
# guard --> right
# guard --> measure
# guard --> deem
# guard --> also
# guard --> limit
# guard --> accept
# guard --> understand
# guard --> include
# guard --> base
# guard --> material
# guard --> transaction
# guard --> appropriate
# guard --> whether
# guard --> seek
# guard --> notify
# guard --> legal
# guard --> circumstance
# guard --> access
# guard --> otherwise
# guard --> permit
# guard --> partner
# guard --> ability
# guard --> communication
# guard --> consent
# guard --> state
# guard --> collect
# guard --> full
# guard --> transmit
# guard --> share
# guard --> locate
# guard --> reasonable
# guard --> person
# guard --> continue
# guard --> purpose
# guard --> law
# guard --> particular
# guard --> compliance
# guard --> additional
# guard --> either
# guard --> electronic
# guard --> govern
# guard --> via
# guard --> available
# guard --> enforce
# guard --> follow
# guard --> express
# guard --> hold
# guard --> set
# guard --> web
# guard --> address
# guard --> may
# guard --> protect
# guard --> provide
# guard --> regard
# guard --> take
# guard --> upon
# guard --> public
# guard --> ask
# guard --> account
# guard --> technical
# guard --> breach
# guard --> term
# guard --> party
# guard --> jurisdiction
# guard --> limited
# guard --> warrant
# guard --> display
# guard --> way
# guard --> data
# guard --> receive
# guard --> sole
# guard --> internet
# guard --> trade
# guard --> part
# guard --> decide
# guard --> country
# guard --> agreement
# guard --> one
# guard --> registration
# guard --> mean
# guard --> transmission
# guard --> information
# guard --> software
# guard --> within
# guard --> give
# guard --> make
# guard --> without
# spyware --> close
# spyware --> least
# spyware --> mark
# spyware --> phone
# spyware --> leave
# spyware --> practice
# spyware --> enter
# spyware --> log
# spyware --> upi
# spyware --> modification
# spyware --> allow
# spyware --> text
# spyware --> grant
# spyware --> india
# spyware --> select
# spyware --> commercial
# spyware --> current
# spyware --> entity
# spyware --> unlawful
# spyware --> store
# spyware --> interactive
# spyware --> year
# spyware --> even
# spyware --> forum
# spyware --> designate
# password --> access
# password --> may
# password --> information
# password --> make
# password --> use
# password --> service
# risk --> may
# risk --> provide
# risk --> term
# risk --> information
# risk --> make
# risk --> use
# distress --> violate
# distress --> read
# distress --> forth
# distress --> policy
# distress --> cannot
# distress --> amendment
# distress --> regulation
# distress --> perform
# distress --> conduct
# distress --> campaign
# distress --> possible
# distress --> product
# distress --> anything
# distress --> due
# distress --> exceed
# distress --> proprietary
# distress --> see
# distress --> result
# distress --> day
# distress --> implied
# distress --> arise
# distress --> marketplace
# distress --> another
# distress --> equipment
# distress --> sensitive
# distress --> order
# distress --> manner
# ...
# trouble --> regardless
# trouble --> system
# trouble --> within
# trouble --> united
# trouble --> event
# trouble --> operator
# trouble --> give
# trouble --> make
# trouble --> different
# trouble --> without
# trouble --> please
# trouble --> option
# trouble --> sit
# trouble --> california
# trouble --> prevent
# trouble --> automatical
# trouble --> group
# trouble --> write
# trouble --> acceptance
# trouble --> change
# trouble --> notice
# trouble --> officer
# trouble --> posting
# trouble --> involve
# trouble --> infringe
# trouble --> distribution
# trouble --> previous
# trouble --> medium
# trouble --> notification
# trouble --> suspect
# trouble --> relate
# trouble --> visit
# trouble --> mobile
# trouble --> relationship
# trouble --> free
# trouble --> identify
# trouble --> accordance
# trouble --> record
# trouble --> online
# trouble --> advertise
# trouble --> us
# trouble --> feature
# trouble --> document
# trouble --> general
# trouble --> code
# trouble --> ensure
# trouble --> contractual
# trouble --> necessary
# trouble --> shall
# trouble --> business
# trouble --> responsible
# trouble --> create
# trouble --> visitor
# trouble --> matter
# trouble --> contract
# trouble --> fee
# trouble --> process
# trouble --> advance
# trouble --> issue
# trouble --> consider
# trouble --> check
# trouble --> month
# trouble --> cooperate
# trouble --> telephone
# trouble --> believe
# trouble --> come
# trouble --> european
# trouble --> membership
# trouble --> test
# trouble --> send
# trouble --> game
# trouble --> comply
# trouble --> assist
# trouble --> time
# trouble --> microsoft
# trouble --> last
# trouble --> age
# trouble --> respond
# trouble --> inability
# trouble --> post
# trouble --> tool
# trouble --> revise
# trouble --> reasonab
# trouble --> functionality
# trouble --> delete
# trouble --> case
# trouble --> apply
# trouble --> use
# trouble --> content
# trouble --> communicate
# trouble --> accuracy
# trouble --> alleged
# trouble --> number
# trouble --> actual
# trouble --> automate
# trouble --> refuse
# trouble --> review
# trouble --> opt
# trouble --> special
# trouble --> various
# trouble --> know
# trouble --> location
# trouble --> infringement
# trouble --> sign
# trouble --> program
# trouble --> error
# trouble --> choose
# trouble --> control
# trouble --> place
# trouble --> link
# trouble --> explicit
# trouble --> period
# trouble --> service
# trouble --> permission
# trouble --> court
# trouble --> social
# trouble --> source
# trouble --> resolution
# trouble --> authority
# trouble --> along
# trouble --> trademark
# trouble --> interaction
# trouble --> wish
# trouble --> certain
# trouble --> treat
# trouble --> outside
# trouble --> click
# trouble --> venue
# trouble --> intend
# trouble --> language
# trouble --> track
# trouble --> legitimate
# trouble --> acquire
# trouble --> close
# trouble --> least
# trouble --> phone
# trouble --> leave
# trouble --> practice
# trouble --> log
# trouble --> allow
# trouble --> text
# trouble --> grant
# trouble --> select
# trouble --> current
# trouble --> play
# trouble --> entity
# trouble --> unlawful
# trouble --> store
# trouble --> image
# trouble --> interactive
# trouble --> year
# trouble --> even
# chargeback --> policy
# chargeback --> cannot
# chargeback --> amendment
# chargeback --> regulation
# chargeback --> perform
# chargeback --> conduct
# chargeback --> product
# chargeback --> anything
# chargeback --> due
# chargeback --> exceed
# chargeback --> result
# chargeback --> day
# chargeback --> arise
# chargeback --> equipment
# chargeback --> order
# chargeback --> manner
# chargeback --> user
# chargeback --> connection
# chargeback --> agree
# chargeback --> clause
# chargeback --> request
# chargeback --> notwithstanding
# chargeback --> claim
# chargeback --> must
# chargeback --> applicable
# chargeback --> remain
# chargeback --> possibility
# chargeback --> violation
# chargeback --> waiver
# chargeback --> total
# chargeback --> unless
# chargeback --> good
# chargeback --> charge
# chargeback --> transfer
# chargeback --> accurate
# chargeback --> work
# chargeback --> become
# chargeback --> copy
# chargeback --> regulatory
# chargeback --> reference
# chargeback --> sale
# chargeback --> loss
# chargeback --> portion
# chargeback --> website
# chargeback --> do
# chargeback --> describe
# chargeback --> payment
# chargeback --> virus
# chargeback --> entire
# chargeback --> activity
# chargeback --> associate
# chargeback --> contact
# chargeback --> right
# chargeback --> implement
# chargeback --> respective
# chargeback --> reason
# chargeback --> settlement
# chargeback --> foreign
# chargeback --> measure
# chargeback --> deem
# chargeback --> relevant
# chargeback --> independent
# chargeback --> unauthorized
# chargeback --> clear
# chargeback --> course
# chargeback --> statement
# chargeback --> also
# chargeback --> delivery
# chargeback --> license
# chargeback --> dispute
# chargeback --> aggregate
# chargeback --> related
# chargeback --> limit
# chargeback --> acknowledge
# chargeback --> understand
# chargeback --> allege
# chargeback --> include
# chargeback --> requirement
# chargeback --> base
# chargeback --> material
# chargeback --> fund
# chargeback --> warranty
# chargeback --> transaction
# chargeback --> confirm
# chargeback --> appropriate
# chargeback --> whether
# chargeback --> refer
# chargeback --> seek
# chargeback --> cause
# chargeback --> need
# chargeback --> contain
# chargeback --> delay
# chargeback --> notify
# chargeback --> legal
# chargeback --> discontinue
# chargeback --> effort
# chargeback --> quality
# chargeback --> fitness
# chargeback --> determine
# chargeback --> bound
# chargeback --> represent
# chargeback --> access
# chargeback --> agent
# chargeback --> direct
# chargeback --> require
# chargeback --> performance
# chargeback --> rule
# chargeback --> copyright
# chargeback --> otherwise
# chargeback --> addition
# chargeback --> indemnity
# chargeback --> amend
# chargeback --> permit
# chargeback --> card
# chargeback --> substitute
# chargeback --> condition
# chargeback --> ability
# chargeback --> communication
# chargeback --> terminate
# chargeback --> endorse
# chargeback --> one
# chargeback --> extent
# chargeback --> might
# chargeback --> mean
# chargeback --> section
# chargeback --> find
# chargeback --> username
# chargeback --> processing
# chargeback --> information
# chargeback --> software
# chargeback --> regardless
# chargeback --> system
# chargeback --> within
# chargeback --> event
# chargeback --> give
# chargeback --> make
# chargeback --> refund
# chargeback --> without
# chargeback --> please
# chargeback --> automatical
# chargeback --> purchase
# chargeback --> acceptance
# chargeback --> change
# chargeback --> mention
# chargeback --> notice
# chargeback --> involve
# chargeback --> tort
# chargeback --> medium
# chargeback --> suspect
# chargeback --> relate
# chargeback --> visit
# chargeback --> standard
# chargeback --> relationship
# chargeback --> free
# chargeback --> withhold
# chargeback --> accordance
# chargeback --> record
# chargeback --> online
# chargeback --> feature
# chargeback --> document
# chargeback --> sell
# chargeback --> general
# chargeback --> contractual
# chargeback --> necessary
# chargeback --> shall
# chargeback --> business
# chargeback --> responsible
# chargeback --> create
# chargeback --> visitor
# chargeback --> matter
# chargeback --> contract
# chargeback --> fee
# chargeback --> process
# chargeback --> maintenance
# chargeback --> issue
# chargeback --> consider
# chargeback --> validity
# chargeback --> month
# chargeback --> support
# chargeback --> responsibility
# chargeback --> send
# chargeback --> comply
# chargeback --> time
# chargeback --> age
# chargeback --> expense
# chargeback --> inability
# chargeback --> post
# chargeback --> reasonab
# chargeback --> use
# chargeback --> content
# chargeback --> communicate
# chargeback --> accuracy
# chargeback --> number
# chargeback --> actual
# chargeback --> review
# chargeback --> occur
# chargeback --> confidential
# chargeback --> know
# chargeback --> termination
# chargeback --> sign
# chargeback --> force
# chargeback --> choose
# chargeback --> control
# chargeback --> place
# chargeback --> period
# chargeback --> maintain
# chargeback --> service
# chargeback --> court
# chargeback --> authority
# chargeback --> facilitate
# chargeback --> connect
# chargeback --> register
# chargeback --> trademark
# chargeback --> advice
# chargeback --> certain
# chargeback --> outside
# chargeback --> duty
# chargeback --> thereof
# chargeback --> offer
# chargeback --> guideline
# chargeback --> least
# chargeback --> mark
# chargeback --> enter
# chargeback --> allow
# chargeback --> grant
# chargeback --> current
# chargeback --> year
# chargeback --> even
# intellectual --> agree
# intellectual --> right
# intellectual --> include
# intellectual --> law
# intellectual --> may
# intellectual --> provide
# intellectual --> term
# intellectual --> make
# intellectual --> use
# intellectual --> content
# intellectual --> service
# property --> include
# property --> may
# property --> provide
# property --> make
# property --> use
# property --> service
# distribute --> may
# distribute --> use
# suspend --> law
# suspend --> may
# suspend --> provide
# suspend --> term
# suspend --> information
# suspend --> without
# suspend --> responsible
# suspend --> use
# suspend --> service
# removed --> violate
# removed --> forth
# removed --> policy
# removed --> cannot
# removed --> product
# removed --> order
# removed --> manner
# removed --> user
# removed --> claim
# removed --> applicable
# removed --> violation
# removed --> others
# removed --> transfer
# removed --> payment
# removed --> activity
# removed --> contact
# removed --> right
# removed --> unauthorized
# removed --> also
# removed --> limit
# removed --> accept
# removed --> acknowledge
# removed --> include
# removed --> appropriate
# removed --> whether
# removed --> seek
# removed --> contain
# removed --> legal
# removed --> determine
# removed --> access
# removed --> direct
# removed --> require
# removed --> permit
# removed --> would
# removed --> consent
# removed --> provider
# removed --> state
# removed --> collect
# removed --> subject
# removed --> share
# removed --> locate
# removed --> reasonable
# removed --> purpose
# removed --> law
# removed --> pay
# removed --> via
# removed --> available
# removed --> follow
# removed --> download
# removed --> express
# removed --> set
# removed --> receipt
# removed --> address
# removed --> may
# removed --> provide
# removed --> behalf
# removed --> federal
# removed --> participate
# removed --> account
# removed --> representative
# removed --> term
# removed --> pursuant
# removed --> party
# removed --> physical
# removed --> jurisdiction
# removed --> limited
# removed --> sole
# removed --> reserve
# removed --> site
# removed --> extent
# removed --> section
# removed --> information
# removed --> within
# removed --> make
# removed --> please
# removed --> purchase
# removed --> relate
# removed --> feature
# removed --> general
# removed --> necessary
# removed --> business
# removed --> create
# removed --> process
# removed --> support
# removed --> send
# removed --> time
# removed --> single
# removed --> post
# removed --> functionality
# removed --> use
# removed --> content
# removed --> review
# removed --> service
# removed --> permission
# removed --> court
# removed --> certain
# removed --> offer
# removed --> remove
# removed --> allow
# removed --> commercial
# removed --> year
# deleted --> agree
# deleted --> unless
# deleted --> work
# deleted --> website
# deleted --> contact
# deleted --> right
# deleted --> also
# deleted --> include
# deleted --> legal
# deleted --> access
# deleted --> follow
# deleted --> may
# deleted --> take
# deleted --> public
# deleted --> account
# deleted --> term
# deleted --> data
# deleted --> part
# deleted --> information
# deleted --> make
# deleted --> necessary
# deleted --> post
# deleted --> use
# deleted --> content
# deleted --> service
# deleted --> offer
# third --> include
# third --> may
# third --> provide
# third --> party
# third --> make
# third --> use
# third --> service
# ['Dubsmash.txt', 'DuckDuckGo.txt', 'Facebook.txt', 'Flickr.txt', 'Github.txt', 'Jabong.txt', 'Loco.txt', 'Microsoft.txt', 'Paytm.txt', 'summary', 'Youtube.txt']
# doing for  Dubsmash.txt
# doing for  DuckDuckGo.txt
# doing for  Facebook.txt
# doing for  Flickr.txt
# doing for  Github.txt
# doing for  Jabong.txt
# doing for  Loco.txt
# doing for  Microsoft.txt
# doing for  Paytm.txt
# doing for  Youtube.txt
# Accuracy for  DubsmashSummary.txt  and  DubsmashGroundTruth.txt  is :  70.37037037037037 %
# Accuracy for  DuckDuckGoSummary.txt  and  DuckDuckGoGroundTruth.txt  is :  60.0 %
# Accuracy for  FacebookSummary.txt  and  FacebookGroundTruth.txt  is :  88.23529411764706 %
# Accuracy for  FlickrSummary.txt  and  FlickrGroundTruth.txt  is :  73.68421052631578 %
# Accuracy for  GithubSummary.txt  and  GithubGroundTruth.txt  is :  78.125 %
# Accuracy for  JabongSummary.txt  and  JabongGroundTruth.txt  is :  77.5 %
# Accuracy for  LocoSummary.txt  and  LocoGroundTruth.txt  is :  82.75862068965517 %
# Accuracy for  MicrosoftSummary.txt  and  MicrosoftGroundTruth.txt  is :  68.42105263157895 %
# Accuracy for  PaytmSummary.txt  and  PaytmGroundTruth.txt  is :  60.86956521739131 %
# Accuracy for  YoutubeSummary.txt  and  youtubeGroundTruth.txt  is :  87.5 %
